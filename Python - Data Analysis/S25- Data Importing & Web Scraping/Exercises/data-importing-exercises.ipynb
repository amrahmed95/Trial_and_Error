# %% [markdown]
# # Data Importing Exercises

# %% [markdown]
# ##### Importing Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set()

# %% [markdown]
# ##### Q. __Import__ the csv-file __cars_raw.csv__ with the appropriate pandas method and __inspect__ the data!

# %%
cars = pd.read_csv(r'G:\Udemy Courses Files\Python Data Analysis Diploma\S25- Data Importing & Web Scraping\importing-materials\assignments\cars_raw.csv')

# %%
cars.head()
# Out:
#                                 Welcome    to            the  \
# Feel   free  to    analyze  and   clean   the          messy
# 18.0  8     307.0 130.0 hp 3504    12.0    70  United States
# 15.0  8     350.0 165.0 hp 3693    11.5    70  United States
# 18.0  8     318.0 150.0 hp 3436    11.0    70  United States
# 16.0  8     304.0 150.0 hp 3433    12.0    70            usa
#
#                                                          cars  Dataset!
# Feel   free  to    analyze  and                       Dataset         !
# 18.0  8     307.0 130.0 hp 3504    chevrolet chevelle malibu        NaN
# 15.0  8     350.0 165.0 hp 3693            buick skylark 320        NaN
# 18.0  8     318.0 150.0 hp 3436           plymouth satellite        NaN
# 16.0  8     304.0 150.0 hp 3433                amc rebel sst        NaN

# %%
cars.tail()
# Out:
#                                           Welcome   to     the  \
# 27.0   4     101.0      83.0 hp  2202        15.3   76  europe
# 17.0   6     250.0      100.0 hp 3329        15.5   71     usa
# 14.5   8     351.0      152.0 hp 4215        12.8   76     usa
# 25.0   6     181.0      110.0 hp 2945        16.4   82     usa
# Thanks  for   analyzing  this     Dataset       !  NaN     NaN
#
#                                                                    cars  \
# 27.0   4     101.0      83.0 hp  2202                     renault 12tl
# 17.0   6     250.0      100.0 hp 3329        chevrolet chevelle malibu
# 14.5   8     351.0      152.0 hp 4215                 ford gran torino
# 25.0   6     181.0      110.0 hp 2945            buick century limited
# Thanks  for   analyzing  this     Dataset                           NaN
#
#                                            Dataset!
# 27.0   4     101.0      83.0 hp  2202           NaN
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 331 entries, ('Feel ', ' free', ' to', ' analyze', ' and') to ('Thanks', ' for ', ' analyzing', ' this', ' Dataset')
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Welcome    331 non-null    object
#  1    to        330 non-null    object
#  2    the       330 non-null    object
#  3    cars      330 non-null    object
#  4    Dataset!  1 non-null      object
# dtypes: object(5)
# memory usage: 35.8+ KB

# %% [markdown]
# ##### Q. Use appropriate __parameters__ in the __pd.read_csv()__ method to clean the format. The following issues need to be solved:
#
# - __Remove__ the __first row(s)__ containing nonsense content.
# - __Remove__ the __last row(s)__ containing nonsense content.
# - Define that there are __no appropriate column labels/headers__ in the data.
# - __Set__ the following __column labels/headers__:
#
# labels = ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model year',
#  'origin',
#  'name']

# %%
labels = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'name']

# %%
cars = pd.read_csv(r'G:\Udemy Courses Files\Python Data Analysis Diploma\S25- Data Importing & Web Scraping\importing-materials\assignments\cars_raw.csv',
                   skiprows=2,
                   skipfooter=1,
                   header=None,
                   names = labels)
# Out:
# C:\Users\Amr Ahmed\AppData\Local\Temp\ipykernel_3732\1212511454.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   cars = pd.read_csv(r'G:\Udemy Courses Files\Python Data Analysis Diploma\S25- Data Importing & Web Scraping\importing-materials\assignments\cars_raw.csv',

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0   130.0 hp    3504          12.0          70
# 1  15.0          8         350.0   165.0 hp    3693          11.5          70
# 2  18.0          8         318.0   150.0 hp    3436          11.0          70
# 3  16.0          8         304.0   150.0 hp    3433          12.0          70
# 4  17.0          8         302.0   140.0 hp    3449          10.5          70
#
#           origin                          name
# 0  United States    chevrolet chevelle malibu
# 1  United States            buick skylark 320
# 2  United States           plymouth satellite
# 3            usa                amc rebel sst
# 4            usa                  FORD TORINO

# %%
cars.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 324  12.0          8         429.0   198.0 hp    4952          11.5
# 325  27.0          4         101.0    83.0 hp    2202          15.3
# 326  17.0          6         250.0   100.0 hp    3329          15.5
# 327  14.5          8         351.0   152.0 hp    4215          12.8
# 328  25.0          6         181.0   110.0 hp    2945          16.4
#
#      model year  origin                          name
# 324          73     usa     mercury marquis brougham
# 325          76  europe                 renault 12tl
# 326          71     usa    chevrolet chevelle malibu
# 327          76     usa             ford gran torino
# 328          82     usa        buick century limited

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           329 non-null    float64
#  1   cylinders     329 non-null    int64
#  2   displacement  329 non-null    float64
#  3   horsepower    329 non-null    object
#  4   weight        329 non-null    int64
#  5   acceleration  329 non-null    float64
#  6   model year    329 non-null    int64
#  7   origin        329 non-null    object
#  8   name          329 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 23.3+ KB

# %% [markdown]
# ##### Q. Once you are happy with the import, __export__ and __save__ cars as new csv-file (__cars_new.csv__). Do __not__ export any __RangeIndex__!

# %%
cars.to_csv('cars_new.csv', index=False)

# %% [markdown]
# ==========

# %% [markdown]
# # GOOD LUCK!
