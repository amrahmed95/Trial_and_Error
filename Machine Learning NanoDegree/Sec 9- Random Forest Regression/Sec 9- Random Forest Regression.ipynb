# %% [markdown]
# #### Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# #### Import Dataset

# %%
dataset = pd.read_csv('../Dataset/Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# #### Fitting Random Forest Regression to the dataset

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0) # n_estimators: Number of trees the algorithm builds before averaging the predictions
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
regressor.predict([[6.5]])
# Out:
# array([167000.])

# %% [markdown]
# #### Visualizing the Random Forest Regression results

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, regressor.predict(X), color = 'blue')
plt.title('Truth or Bluff (Random Forest Regression Model)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# #### Visualizing the Random Forest Regression results (For higher resolution and smoother curve)

# %%
x_grid = np.arange(min(X), max(X), 0.001)
x_grid = x_grid.reshape((len(x_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(x_grid, regressor.predict(x_grid), color = 'blue')
plt.title('Truth or Bluff (Random Forest Regression Model)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\Amr Ahmed\AppData\Local\Temp\ipykernel_9084\2973286792.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(X), max(X), 0.001)
